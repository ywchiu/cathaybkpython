# %%
import pandas
df = pandas.read_csv('data/part1.txt', encoding = 'utf-8', sep= '\t', na_values='?', header=None)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2852704 entries, 0 to 2852703
# Data columns (total 14 columns):
# 0     object
# 1     float64
# 2     float64
# 3     int64
# 4     int64
# 5     int64
# 6     int64
# 7     float64
# 8     float64
# 9     object
# 10    object
# 11    float64
# 12    float64
# 13    float64
# dtypes: float64(7), int64(4), object(3)
# memory usage: 304.7+ MB

# %%
df.columns = ['cookie_id','週間造訪次數','週末造訪次數','早上造訪次數','下午造訪次數','晚上造訪次數','凌晨造訪次數','Latitude','Longitude',
 'City','Country','AVG_PAGE','ACTIVE_TIME','oneline_visit']

# %%
df.head()
# Out:
#                           cookie_id  週間造訪次數  週末造訪次數  早上造訪次數  下午造訪次數  晚上造訪次數  \
# 0  f23e7f226f504677a4ca890cd296413f    21.0     0.0      69     171       0
# 1  f1a44ccf03b9465c918325d6e0752176     1.0     0.0       0       1       0
# 2  2662293ab50743ae9a0ff1940fdecca3     3.0     0.0       1       2       0
# 3  ef24f613991e4c618aa2e57a3ddd0a52     1.0     0.0       0       7       0
# 4  f327275a8dbd406c8aacf4fb809a9b92     1.0     0.0       0       0       1
#
#    凌晨造訪次數  Latitude   Longitude       City Country  AVG_PAGE  ACTIVE_TIME  \
# 0       0   22.6333  120.350006  Kaohsiung  Taiwan       3.0         3.41
# 1       0   25.0392  121.524994     Taipei  Taiwan      13.0        11.95
# 2       0   25.0392  121.524994     Taipei  Taiwan       9.0         7.73
# 3       0   25.0392  121.524994     Taipei  Taiwan      16.0         9.59
# 4       0   23.5000  121.000000        NaN  Taiwan       1.0         0.26
#
#    oneline_visit
# 0            0.0
# 1            0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2852703 entries, 0 to 2852702
# Data columns (total 14 columns):
# cookie_id        object
# 週間造訪次數           float64
# 週末造訪次數           float64
# 早上造訪次數           int64
# 下午造訪次數           int64
# 晚上造訪次數           int64
# 凌晨造訪次數           int64
# Latitude         float64
# Longitude        float64
# City             object
# Country          object
# AVG_PAGE         float64
# ACTIVE_TIME      float64
# oneline_visit    float64
# dtypes: float64(7), int64(4), object(3)
# memory usage: 304.7+ MB

# %%
df = df.dropna()

# %%
df.describe()
# Out:
#              週間造訪次數        週末造訪次數        早上造訪次數        下午造訪次數        晚上造訪次數  \
# count  2.065565e+06  2.065565e+06  2.065565e+06  2.065565e+06  2.065565e+06
# mean   3.673468e+00  5.783420e-01  1.624173e+01  1.335775e+01  6.461512e+00
# std    9.017863e+00  1.597744e+00  3.810144e+02  3.360311e+02  1.616655e+02
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    3.000000e+00  1.000000e+00  2.000000e+00  2.000000e+00  1.000000e+00
# max    6.500000e+02  1.700000e+02  3.655570e+05  3.427100e+05  1.782080e+05
#
#              凌晨造訪次數      Latitude     Longitude      AVG_PAGE   ACTIVE_TIME  \
# count  2.065565e+06  2.065565e+06  2.065565e+06  2.065565e+06  2.065565e+06
# mean   1.658308e+00  2.543388e+01  1.105778e+02  3.903775e+00  2.548130e+00
# ...

# %%
#df[df['ACTIVE_TIME'] == df['ACTIVE_TIME'].max()]
df[df['AVG_PAGE'] == df['AVG_PAGE'].max()]
# Out:
#                                cookie_id  週間造訪次數  週末造訪次數  早上造訪次數  下午造訪次數  \
# 490400  5bdcbade218545fa947a4673c3d5cfa9    10.0     1.0       9       1
#
#         晚上造訪次數  凌晨造訪次數   Latitude   Longitude     City Country  AVG_PAGE  \
# 490400       6       1  24.804703  120.971405  Hsinchu  Taiwan     779.0
#
#         ACTIVE_TIME  oneline_visit
# 490400        24.53            0.0

# %%
df.sort(['AVG_PAGE'], ascending=[0]).head(10)
# Out:
# C:\Anaconda32\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#                                 cookie_id  週間造訪次數  週末造訪次數  早上造訪次數  下午造訪次數  \
# 490400   5bdcbade218545fa947a4673c3d5cfa9    10.0     1.0       9       1
# 2408745  cd2882a08a84402db6b50b07591bc0f9     1.0     0.0       0       1
# 2056558  43f54d5341f94e55a04b9bed79c9be7c     7.0     0.0       0       0
# 866420   23778c878f91487e9008593e4be374b7     4.0     0.0       2      24
# 1161737  d9c88dcb307b4023a67f60120bead7e4     7.0     0.0       7       0
# 1689575  b4b9b99c6cfb49748f723b87675d48ba     1.0     0.0       1       0
# 248523   613fe6f45abe4ed68ac6b739dc279930    42.0     0.0      41       1
# 1332747  34981b7bd06b4282a21cabbf129883db     1.0     0.0       0       0
# 2120260  a6347f35bd00405a8d8a17f0193fbd3a     4.0     0.0       6       0
# ...

# %%
import requests

headers = {
'User-Agent':'qoo'
}
res = requests.get('http://mic.largitdata.com', headers = headers)
print(res)
# Out:
# <Response [200]>

# %%
df.sort(['週間造訪次數'], ascending=[0]).head(10)
# Out:
# C:\Anaconda32\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#                                 cookie_id  週間造訪次數  週末造訪次數  早上造訪次數  下午造訪次數  \
# 354738   780fd682956b4c49bbeb1d57b4e5a4bc  1142.0     4.0     713     412
# 737642   06308cf3124344738d2712f3362cf2ec   851.0     8.0     481     352
# 2176315  dc4f9a4354264a5684cca69d2a0a64d8   652.0     5.0     364     281
# 2103526  81dc61801c924c39a00f93b14c3ff383   650.0     0.0     408     275
# 972923   28e440629fd842b2b4d22e6ca7a2e63d   569.0    36.0   73972   52632
# 2109445  5f0bd578e509462e9cddc0ff485f27a2   552.0     9.0     344     196
# 1455504  2bec630bbcb74c90bac5289ba506fe45   536.0     3.0     317     211
# 2547359  70c2442656094d1f8608abc976dfd66b   533.0    10.0     287     226
# 1264535  de0f7ec7b4684d4f8b95c02aab8ce8ee   533.0     4.0     260     264
# ...

# %%
df.sort(['早上造訪次數'], ascending=[0]).head(10)
# Out:
# C:\Anaconda32\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#                                 cookie_id  週間造訪次數  週末造訪次數  早上造訪次數  下午造訪次數  \
# 1739103  49b488ab2d144d51aa7eacbf843221d9    75.0     0.0  365557  342710
# 2558974  df8b8ffcad16411f8f6c9a6aaf231c77    86.0    18.0  148119   73108
# 2734471  a5f080663f8e4c87abff984f8f10c8a3    41.0     0.0  126871   14982
# 1814965  ab73182b438f41c6ace5a01394c154d3    16.0     0.0  114235   22851
# 1153821  a5f712acb5f14162951531b57ad088d0    78.0     0.0   95307   77909
# 2016436  a8306be781d5496ba677272525630b06   123.0    29.0   94664   50104
# 44379    57ba354ce0224828b631b8059fa66ac2   154.0    13.0   85892   46965
# 972923   28e440629fd842b2b4d22e6ca7a2e63d   569.0    36.0   73972   52632
# 983689   a376b1adae0d4d54839b813b88277e1e   208.0    26.0   70040   75420
# ...

# %%
# %pylab inline
df['ACTIVE_TIME'].plot(kind='hist', bins=100, figsize=[20,20], logx=True)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df['ACTIVE_TIME'].plot(kind='box',figsize=[20,20])

# %%
df[['早上造訪次數', '下午造訪次數', '晚上造訪次數', '凌晨造訪次數']].plot(kind='box',figsize=[20,20], logy=True)

# %%
df[df['City'] =='Ashburn']
# Out:
#                                 cookie_id  週間造訪次數  週末造訪次數  早上造訪次數  下午造訪次數  \
# 52       e6704053c40f4cd2b77f47a87945b3f2     1.0     0.0       0       0
# 298      02c3eab30aa94f79a28b71c4361e3a4a     1.0     0.0       0       1
# 505      02d61bd871c84c568bc956ddcc3461d8     0.0     1.0       0       1
# 512      e031250aa36144e6be498c5a2ac3a8b3     1.0     0.0       0       1
# 557      21b3e3987309456a89bf7aeda84db61b     1.0     0.0       1       0
# 558      c7b7e4c1515343b782fa20f8bd420a80     0.0     1.0       0       1
# 581      01bf85008a2b4471975ae74c0237e55d     0.0     1.0       1       0
# 668      28e41e2dd5db4e6dafaa7cd70cc44e4c     1.0     0.0       0       0
# 705      02c23407ea3a427d9a081707731b5f94     1.0     0.0       1       0
# 860      874cc871d3d04ed7916740549b13cb54     1.0     0.0       0       0
# 914      1469ce00c2f841cca6635a10e208d25b     0.0     1.0       0       1
# 974      528ac109af5f4bdf9b80858354798a6e     0.0     1.0       1       0
# ...

# %%
df[['cookie_id','City']].groupby('City').count().sort_values('cookie_id')
# Out:
#                   cookie_id
# City
# Kishiwada                 1
# East Hampton              1
# East Greenwich            1
# Lucca                     1
# East Fremantle            1
# Ph? Long                  1
# East Amherst              1
# Earlwood                  1
# Phan Thiet                1
# East Hanover              1
# Eagle River               1
# D黵en                      1
# Dyersburg                 1
# Phatthalung               1
# Phayao                    1
# Loxton                    1
# Inashiki                  1
# Dunsborough               1
# Dungun                    1
# Imus                      1
# Petaluma                  1
# East London               1
# East Northport            1
# Patchogue                 1
# Pathankot                 1
# Pavia Di Udine            1
# Edgewater                 1
# Edenvale                  1
# Edensor Park              1
# Ikeja                     1
# ...                     ...
# Zhongxiqu              1551
# ...

# %%
df[df.Country == 'Taiwan']['ACTIVE_TIME'].plot(kind='hist', bins=100, figsize=[20,20], logx=True)
